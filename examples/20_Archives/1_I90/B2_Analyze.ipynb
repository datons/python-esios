# %% [markdown]
# # Analyze

# %% [markdown]
# ## Load files

# %% [markdown]
# - I90DIA27: Bilateral

# %%
import pandas as pd

df_base = pd.read_excel(
    'data/I90DIA/I90DIA_20240221.xls',
    sheet_name='I90DIA27', skiprows=3, index_col=[0,1,2]
).iloc[:,2:]

df_base
# Out:
#                                                 00-01  01-02  02-03  03-04  \
# Unidad de Programación Tipo Oferta Nº contrato
# ACSOC01                8           2357          -1.9   -1.9   -1.9   -1.9
# ADSEC01                8           2354          -0.5   -0.4   -0.4   -0.3
# ...                                               ...    ...    ...    ...
# WKWC01                 8           2346          -1.7   -1.5   -1.3   -1.3
# YELLC01                8           2001        -112.4 -109.4 -108.1 -108.4
#
#                                                 04-05  05-06  06-07  07-08  \
# Unidad de Programación Tipo Oferta Nº contrato
# ACSOC01                8           2357          -2.0   -2.1   -2.6   -3.5
# ADSEC01                8           2354          -0.3   -0.4   -0.4   -0.5
# ...                                               ...    ...    ...    ...
# WKWC01                 8           2346          -1.3   -1.3   -1.4   -1.8
# YELLC01                8           2001        -108.9 -116.5 -151.4 -187.8
#
#                                                 08-09  09-10  ...  14-15  \
# Unidad de Programación Tipo Oferta Nº contrato                ...
# ACSOC01                8           2357          -4.3   -4.5  ...   -3.8
# ADSEC01                8           2354          -0.6   -0.6  ...   -0.6
# ...                                               ...    ...  ...    ...
# WKWC01                 8           2346          -2.1   -2.3  ...   -2.1
# YELLC01                8           2001        -216.4 -218.5  ... -172.4
#
#                                                 15-16  16-17  17-18  18-19  \
# Unidad de Programación Tipo Oferta Nº contrato
# ACSOC01                8           2357          -3.7   -3.5   -3.3   -3.2
# ADSEC01                8           2354          -0.6   -0.6   -0.6   -0.6
# ...                                               ...    ...    ...    ...
# WKWC01                 8           2346          -2.0   -2.0   -2.1   -2.3
# YELLC01                8           2001        -173.4 -179.9 -186.9 -184.3
#
#                                                 19-20  20-21  21-22  22-23  \
# Unidad de Programación Tipo Oferta Nº contrato
# ACSOC01                8           2357          -3.1   -3.0   -2.7   -2.5
# ADSEC01                8           2354          -0.7   -0.8   -0.7   -0.7
# ...                                               ...    ...    ...    ...
# WKWC01                 8           2346          -2.7   -2.8   -2.6   -2.4
# YELLC01                8           2001        -181.2 -171.0 -157.0 -142.5
#
#                                                 23-24
# Unidad de Programación Tipo Oferta Nº contrato
# ACSOC01                8           2357          -2.3
# ADSEC01                8           2354          -0.6
# ...                                               ...
# WKWC01                 8           2346          -2.0
# YELLC01                8           2001        -133.3
#
# [511 rows x 24 columns]

# %% [markdown]
# ## Data preprocessing

# %%
import numpy as np

df = df_base.melt(ignore_index=False).reset_index()
df.columns = ['unit', 'offer_type', 'contract', 'hour', 'value']

date = '20240221'
hour = df.hour.str.split('-', expand=True)[0]
df['datetime'] = pd.to_datetime(date + ' ' + hour)

df['agent'] = np.where(df.value > 0, 'Buyer', 'Seller')
df
# Out:
#           unit  offer_type  contract   hour  value            datetime   agent
# 0      ACSOC01           8      2357  00-01   -1.9 2024-02-21 00:00:00  Seller
# 1      ADSEC01           8      2354  00-01   -0.5 2024-02-21 00:00:00  Seller
# ...        ...         ...       ...    ...    ...                 ...     ...
# 12262   WKWC01           8      2346  23-24   -2.0 2024-02-21 23:00:00  Seller
# 12263  YELLC01           8      2001  23-24 -133.3 2024-02-21 23:00:00  Seller
#
# [12264 rows x 7 columns]

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# ### Units involved in contracts

# %%
df_base = df.copy()

# %%
df_base.pivot_table(index='unit', columns='contract', values='value', aggfunc='sum').iloc[:20,:20].style.format(precision=0).highlight_null(props='color: transparent')
# Out:
# <style type="text/css">
# #T_3c647_row0_col0, #T_3c647_row0_col1, #T_3c647_row0_col2, #T_3c647_row0_col3, #T_3c647_row0_col4, #T_3c647_row0_col5, #T_3c647_row0_col6, #T_3c647_row0_col7, #T_3c647_row0_col8, #T_3c647_row0_col9, #T_3c647_row0_col10, #T_3c647_row0_col11, #T_3c647_row0_col12, #T_3c647_row0_col13, #T_3c647_row0_col14, #T_3c647_row0_col15, #T_3c647_row0_col16, #T_3c647_row0_col17, #T_3c647_row0_col18, #T_3c647_row0_col19, #T_3c647_row1_col0, #T_3c647_row1_col1, #T_3c647_row1_col2, #T_3c647_row1_col3, #T_3c647_row1_col4, #T_3c647_row1_col5, #T_3c647_row1_col6, #T_3c647_row1_col7, #T_3c647_row1_col8, #T_3c647_row1_col9, #T_3c647_row1_col10, #T_3c647_row1_col11, #T_3c647_row1_col12, #T_3c647_row1_col13, #T_3c647_row1_col14, #T_3c647_row1_col15, #T_3c647_row1_col16, #T_3c647_row1_col17, #T_3c647_row1_col18, #T_3c647_row1_col19, #T_3c647_row2_col0, #T_3c647_row2_col1, #T_3c647_row2_col2, #T_3c647_row2_col3, #T_3c647_row2_col4, #T_3c647_row2_col5, #T_3c647_row2_col6, #T_3c647_row2_col7, #T_3c647_row2_col8, #T_3c647_row2_col9, #T_3c647_row2_col10, #T_3c647_row2_col11, #T_3c647_row2_col12, #T_3c647_row2_col13, #T_3c647_row2_col14, #T_3c647_row2_col15, #T_3c647_row2_col16, #T_3c647_row2_col17, #T_3c647_row2_col18, #T_3c647_row2_col19, #T_3c647_row3_col0, #T_3c647_row3_col1, #T_3c647_row3_col2, #T_3c647_row3_col3, #T_3c647_row3_col4, #T_3c647_row3_col5, #T_3c647_row3_col6, #T_3c647_row3_col7, #T_3c647_row3_col8, #T_3c647_row3_col9, #T_3c647_row3_col10, #T_3c647_row3_col11, #T_3c647_row3_col12, #T_3c647_row3_col13, #T_3c647_row3_col14, #T_3c647_row3_col15, #T_3c647_row3_col16, #T_3c647_row3_col17, #T_3c647_row4_col0, #T_3c647_row4_col1, #T_3c647_row4_col2, #T_3c647_row4_col3, #T_3c647_row4_col4, #T_3c647_row4_col5, #T_3c647_row4_col6, #T_3c647_row4_col7, #T_3c647_row4_col8, #T_3c647_row4_col9, #T_3c647_row4_col10, #T_3c647_row4_col11, #T_3c647_row4_col12, #T_3c647_row4_col13, #T_3c647_row4_col14, #T_3c647_row4_col15, #T_3c647_row4_col16, #T_3c647_row4_col17, #T_3c647_row4_col18, #T_3c647_row4_col19, #T_3c647_row5_col0, #T_3c647_row5_col1, #T_3c647_row5_col2, #T_3c647_row5_col3, #T_3c647_row5_col4, #T_3c647_row5_col5, #T_3c647_row5_col6, #T_3c647_row5_col7, #T_3c647_row5_col8, #T_3c647_row5_col9, #T_3c647_row5_col10, #T_3c647_row5_col11, #T_3c647_row5_col12, #T_3c647_row5_col13, #T_3c647_row5_col14, #T_3c647_row5_col15, #T_3c647_row5_col16, #T_3c647_row5_col17, #T_3c647_row5_col18, #T_3c647_row5_col19, #T_3c647_row6_col0, #T_3c647_row6_col1, #T_3c647_row6_col2, #T_3c647_row6_col3, #T_3c647_row6_col4, #T_3c647_row6_col5, #T_3c647_row6_col6, #T_3c647_row6_col7, #T_3c647_row6_col8, #T_3c647_row6_col9, #T_3c647_row6_col10, #T_3c647_row6_col11, #T_3c647_row6_col12, #T_3c647_row6_col14, #T_3c647_row6_col15, #T_3c647_row6_col16, #T_3c647_row6_col17, #T_3c647_row6_col18, #T_3c647_row6_col19, #T_3c647_row7_col0, #T_3c647_row7_col1, #T_3c647_row7_col2, #T_3c647_row7_col3, #T_3c647_row7_col4, #T_3c647_row7_col5, #T_3c647_row7_col6, #T_3c647_row7_col7, #T_3c647_row7_col8, #T_3c647_row7_col9, #T_3c647_row7_col10, #T_3c647_row7_col11, #T_3c647_row7_col12, #T_3c647_row7_col14, #T_3c647_row7_col15, #T_3c647_row7_col16, #T_3c647_row7_col17, #T_3c647_row7_col18, #T_3c647_row7_col19, #T_3c647_row8_col0, #T_3c647_row8_col1, #T_3c647_row8_col2, #T_3c647_row8_col3, #T_3c647_row8_col4, #T_3c647_row8_col5, #T_3c647_row8_col6, #T_3c647_row8_col7, #T_3c647_row8_col8, #T_3c647_row8_col9, #T_3c647_row8_col10, #T_3c647_row8_col11, #T_3c647_row8_col12, #T_3c647_row8_col13, #T_3c647_row8_col14, #T_3c647_row8_col15, #T_3c647_row8_col16, #T_3c647_row8_col17, #T_3c647_row8_col18, #T_3c647_row8_col19, #T_3c647_row9_col0, #T_3c647_row9_col2, #T_3c647_row9_col3, #T_3c647_row9_col4, #T_3c647_row9_col5, #T_3c647_row9_col6, #T_3c647_row9_col7, #T_3c647_row9_col8, #T_3c647_row9_col9, #T_3c647_row9_col10, #T_3c647_row9_col11, #T_3c647_row9_col12, #T_3c647_row9_col13, #T_3c647_row9_col14, #T_3c647_row9_col15, #T_3c647_row9_col16, #T_3c647_row9_col17, #T_3c647_row9_col18, #T_3c647_row9_col19, #T_3 ...

# %% [markdown]
# ### Unit specific involved in contracts

# %%
unit = "ENDE01"
contracts = df_base.query('unit == @unit').contract.unique()
contracts
# Out:
# array([1019, 1513, 1994, 2293, 2193, 2330])

# %%
mask = df_base.contract.isin(contracts)
df = df_base[mask]
df
# Out:
#        unit  offer_type  contract   hour  value            datetime   agent
# 12     ALZ1           1      1994  00-01    NaN 2024-02-21 00:00:00  Seller
# 16     ALZ2           1      1994  00-01    NaN 2024-02-21 00:00:00  Seller
# ...     ...         ...       ...    ...    ...                 ...     ...
# 12214  TERE           1      1513  23-24    NaN 2024-02-21 23:00:00  Seller
# 12241  VAN2           1      1513  23-24    NaN 2024-02-21 23:00:00  Seller
#
# [696 rows x 7 columns]

# %%
df.groupby(['unit', 'agent']).value.sum().unstack('agent').sort_values('Buyer', ascending=False).fillna(0).style.format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0119a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >agent</th>
#       <th id="T_0119a_level0_col0" class="col_heading level0 col0" >Buyer</th>
#       <th id="T_0119a_level0_col1" class="col_heading level0 col1" >Seller</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >unit</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0119a_level0_row0" class="row_heading level0 row0" >ASC1</th>
#       <td id="T_0119a_row0_col0" class="data row0 col0" >2985</td>
#       <td id="T_0119a_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row1" class="row_heading level0 row1" >ASC2</th>
#       <td id="T_0119a_row1_col0" class="data row1 col0" >2526</td>
#       <td id="T_0119a_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row2" class="row_heading level0 row2" >VAN2</th>
#       <td id="T_0119a_row2_col0" class="data row2 col0" >2256</td>
#       <td id="T_0119a_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row3" class="row_heading level0 row3" >EBRFEN</th>
#       <td id="T_0119a_row3_col0" class="data row3 col0" >1644</td>
#       <td id="T_0119a_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row4" class="row_heading level0 row4" >SBEU</th>
#       <td id="T_0119a_row4_col0" class="data row4 col0" >1230</td>
#       <td id="T_0119a_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row5" class="row_heading level0 row5" >ENDE01</th>
#       <td id="T_0119a_row5_col0" class="data row5 col0" >589</td>
#       <td id="T_0119a_row5_col1" class="data row5 col1" >-12182</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row6" class="row_heading level0 row6" >ALZ2</th>
#       <td id="T_0119a_row6_col0" class="data row6 col0" >342</td>
#       <td id="T_0119a_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row7" class="row_heading level0 row7" >ALZ1</th>
#       <td id="T_0119a_row7_col0" class="data row7 col0" >342</td>
#       <td id="T_0119a_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row8" class="row_heading level0 row8" >EREGPE1</th>
#       <td id="T_0119a_row8_col0" class="data row8 col0" >149</td>
#       <td id="T_0119a_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row9" class="row_heading level0 row9" >EREGPEM</th>
#       <td id="T_0119a_row9_col0" class="data row9 col0" >128</td>
#       <td id="T_0119a_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row10" class="row_heading level0 row10" >EEGPEM</th>
#       <td id="T_0119a_row10_col0" class="data row10 col0" >126</td>
#       <td id="T_0119a_row10_col1" class="data row10 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row11" class="row_heading level0 row11" >GDLQ</th>
#       <td id="T_0119a_row11_col0" class="data row11 col0" >115</td>
#       <td id="T_0119a_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row12" class="row_heading level0 row12" >GDNA</th>
#       <td id="T_0119a_row12_col0" class="data row12 col0" >102</td>
#       <td id="T_0119a_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row13" class="row_heading level0 row13" >TEES</th>
#       <td id="T_0119a_row13_col0" class="data row13 col0" >60</td>
#       <td id="T_0119a_row13_col1" class="data row13 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row14" class="row_heading level0 row14" >FEGPE1</th>
#       <td id="T_0119a_row14_col0" class="data row14 col0" >47</td>
#       <td id="T_0119a_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row15" class="row_heading level0 row15" >FREGPEM</th>
#       <td id="T_0119a_row15_col0" class="data row15 col0" >46</td>
#       <td id="T_0119a_row15_col1" class="data row15 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row16" class="row_heading level0 row16" >HEGPE</th>
#       <td id="T_0119a_row16_col0" class="data row16 col0" >34</td>
#       <td id="T_0119a_row16_col1" class="data row16 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row17" class="row_heading level0 row17" >FEGPEM</th>
#       <td id="T_0119a_row17_col0" class="data row17 col0" >24</td>
#       <td id="T_0119a_row17_col1" class="data row17 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row18" class="row_heading level0 row18" >FEGPE2</th>
#       <td id="T_0119a_row18_col0" class="data row18 col0" >12</td>
#       <td id="T_0119a_row18_col1" class="data row18 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row19" class="row_heading level0 row19" >TERE</th>
#       <td id="T_0119a_row19_col0" class="data row19 col0" >6</td>
#       <td id="T_0119a_row19_col1" class="data row19 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row20" class="row_heading level0 row20" >FREGPE</th>
#       <td id="T_0119a_row20_col0" class="data row20 col0" >5</td>
#       <td id="T_0119a_row20_col1" class="data row20 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row21" class="row_heading level0 row21" >FEGPE</th>
#       <td id="T_0119a_row21_col0" class="data row21 col0" >4</td>
#       <td id="T_0119a_row21_col1" class="data row21 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row22" class="row_heading level0 row22" >ECAZC01</th>
#       <td id="T_0119a_row22_col0" class="data row22 col0" >0</td>
#       <td id="T_0119a_row22_col1" class="data row22 col1" >-578</td>
#     </tr>
#     <tr>
#       <th id="T_0119a_level0_row23" class="row_heading level0 row23" >EPRSC01</th>
#       <td id="T_0119a_row23_col0" class="data row23 col0" >0</td>
#       <td id="T_0119a_row23_col1" class="data row23 col1" >-12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## References
#
# https://www.energychisquared.com/post/tipos-de-bilaterales-en-el-sistema-el%C3%A9ctrico/
