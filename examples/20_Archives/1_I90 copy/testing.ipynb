# %%
path = 'data/I90DIA/I90DIA_20240101/I90DIA_20240101.xls'

# %%
from esios.archives import preprocessing

df = preprocessing.process_excel_file(path, sheet_name='I90DIA03')
df
# Out:
#      Redespacho Sentido Unidad de Programación  Nm Oferta asignada  \
# 0       UPOPVPV   Subir                   ABO2          31127409.0
# 1       UPOPVPV   Subir                   ACE4          31127451.0
# ...         ...     ...                    ...                 ...
# 4222     ECOBSO   Bajar                  ERIO2                -1.0
# 4223     ECOBSO   Bajar                 ERIO2A                -1.0
#
#       Tipo Oferta Tipo cálculo Tipo Restricción                  datetime  \
# 0             1.0     Complejo              RTD 2024-01-01 00:00:00+01:00
# 1             1.0     Complejo              SOT 2024-01-01 00:00:00+01:00
# ...           ...          ...              ...                       ...
# 4222         10.0    No aplica              N/A 2024-01-01 23:00:00+01:00
# 4223         10.0    No aplica              N/A 2024-01-01 23:00:00+01:00
#
#       value
# 0       NaN
# 1     116.6
# ...     ...
# 4222   -0.5
# 4223   -1.1
#
# [4224 rows x 9 columns]
