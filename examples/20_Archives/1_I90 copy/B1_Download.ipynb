# %% [markdown]
# # Archives endpoint

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Instantiate the client and endpoint

# %%
from esios import ESIOSClient
client = ESIOSClient()
endpoint = client.endpoint(name='archives')

# %% [markdown]
# https://www.esios.ree.es/es/descargas

# %% [markdown]
# ## Select archive

# %% [markdown]
# - I90DIA: 34
# - https://api.esios.ree.es/archives/34/download?date_type=real&end_date=2024-04-21T23%3A59%3A59%2B00%3A00&locale=es&start_date=2024-04-01T00%3A00%3A00%2B00%3A00

# %%
archive = endpoint.select(id=34)

# %% [markdown]
# ## Configure query

# %%
archive.configure(date_type='real', start='2020-01-01', end='2024-12-31')

# %% [markdown]
# ## See metadata

# %%
archive.metadata
# Out:
# {'archive': {'name': 'I90DIA',
#   'description': 'Información de detalle por Unidad de Programación (I90DIA)',
#   'updated_at': '2015-01-29 09:20:49.0',
#   'id': 34,
#   'horizon': 'D',
#   'archive_type': 'zip',
#   'download': {'name': 'I90DIA',
#    'url': '/archives/34/download?date_type=real&end_date=2024-12-31T23%3A59%3A59%2B00%3A00&locale=es&start_date=2020-01-01T00%3A00%3A00%2B00%3A00'},
#   'date': {'date_type': 'real',
#    'start_date': '2020-01-01 00:00:00.000+0100',
#    'end_date': '2024-12-31 23:59:59.000+0100'},
#   'date_times': ['2020-01-01', '2024-09-22'],
#   'publication_date': ['2020-03-31', '2024-12-21'],
#   'taxonomy_terms': [{'id_taxonomy_term': 155,
#     'name': 'Generación y consumo',
#     'vocabulary_id': 20},
#    {'id_taxonomy_term': 156,
#     'name': 'Mercados y precios',
#     'vocabulary_id': 20},
#    {'id_taxonomy_term': 165, 'name': 'Descargas', 'vocabulary_id': 21},
#    {'id_taxonomy_term': 168, 'name': 'General', 'vocabulary_id': 22}],
#   'vocabularies': [{'id_vocabulary': 20, 'name': 'Universo'},
#    {'id_vocabulary': 21, 'name': 'Temática'},
#    {'id_vocabulary': 22, 'name': 'Área'}]}}

# %% [markdown]
# ## Download and extract data files

# %%
archive.download_and_extract(output_dir='data')
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 archive.download_and_extract(output_dir='data')
#
# File ~/Library/CloudStorage/Dropbox-datons/Jesús López/4 Software Programs/2 API Wrappers/ESIOS API/1 Repository/python-esios-v2/esios/archives/__init__.py:120, in Archive.download_and_extract(self, output_dir)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Library/CloudStorage/Dropbox-datons/Jesús López/4 Software Programs/2 API Wrappers/ESIOS API/1 Repository/python-esios-v2/esios/archives/__init__.py:129, in _extract_zip(self, file, directory)
#     126 def _extract_zip(self, file, directory):
#     127     """
#     128     Extracts a ZIP file to the specified directory. If there are nested ZIP files,
# --> 129     they are extracted recursively.
#     130     """
#     131     with zipfile.ZipFile(file) as z:
#     132         z.extractall(directory)
#
# File ~/miniforge3/envs/cloud/lib/python3.12/zipfile/__init__.py:1349, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1347 try:
#    1348     if mode == 'r':
# -> 1349         self._RealGetContents()
#    1350     elif mode in ('w', 'x'):
#    1351         # set the modified flag so central directory gets written
#    1352         # even if no files are added to the archive
#    1353         self._didModify = True
#
# File ~/miniforge3/envs/cloud/lib/python3.12/zipfile/__init__.py:1416, in ZipFile._RealGetContents(self)
#    1414     raise BadZipFile("File is not a zip file")
#    1415 if not endrec:
# -> 1416     raise BadZipFile("File is not a zip file")
#    1417 if self.debug > 1:
#    1418     print(endrec)
#
# BadZipFile: File is not a zip file
