# %% [markdown]
# # ESIOS API
# https://api.esios.ree.es/

# %% [markdown]
# ## Endpoints
#
# **Indicators**
#
# https://www.esios.ree.es/es/analisis
#
# <img src="src/ESIOS-INDICADORES.png" width=400>
#
# **Archives**
#
# https://www.esios.ree.es/es/descargas
#
# <img src="src/ESIOS-DESCARGAS.png" width=400>

# %% [markdown]
# ## Install library

# %%
# !pip install python-esios

# %% [markdown]
# ## Library structure

# %%
import esios
client = esios.ESIOSClient()

# %% [markdown]
# ### Indicators
#
# https://www.esios.ree.es/es/analisis

# %%
df = endpoint.list()
df
# Out:
#                                                    name  \
# 0              Generación programada PBF Hidráulica UGH
# 1           Generación programada PBF Hidráulica no UGH
# ...                                                 ...
# 1937  RD-L 10/2022 restricciones técnicas y mercados...
# 1938  Precio medio ponderado de activación del servi...
#
#                                             description  \
# 0     Es el programa de energía diario, con desglose...
# 1     Es el programa de energía diario, con desglose...
# ...                                                 ...
# 1937  RD-L 10/2022 restricciones técnicas y mercados...
# 1938   Es un servicio específico de balance del sist...
#
#                                              short_name     id
# 0                                        Hidráulica UGH      1
# 1                                     Hidráulica no UGH      2
# ...                                                 ...    ...
# ...

# %% [markdown]
# ### Archives
#
# https://www.esios.ree.es/es/descargas

# %%
df = endpoint.archives.list()
df
# Out:
#                              name   id horizon archive_type  \
# 0           REE_BalancingEnerBids  181      QM          csv
# 1   Resultado_Subasta_Mensual_POR  159       M          xls
# ..                            ...  ...     ...          ...
# 24                       totalp48   29       H          xml
# 25                  totalrp48prec   27       H          xml
#
#                                              download  \
# 0   {'name': 'REE_BalancingEnerBids', 'url': '/arc...
# 1   {'name': 'Resultado_Subasta_Mensual_POR', 'url...
# ..                                                ...
# 24  {'name': 'totalp48', 'url': '/archives/29/down...
# 25  {'name': 'totalrp48prec', 'url': '/archives/27...
#
#                                          date    date_times publication_date  \
# 0   {'date': '2024-05-25T23:59:59.000+02:00'}            []     [2024-05-25]
# 1   {'date': '2024-05-25T23:59:59.000+02:00'}            []     [2024-04-24]
# ...

# %%
df = endpoint.archives.list(start='2023-01-01', end='2023-12-31')
df
# Out:
#               name   id horizon archive_type  \
# 0   C2_PrecioFinal  187       M          zip
# 1   C5_PrecioFinal  188       M          zip
# ..             ...  ...     ...          ...
# 52  totalrpdvpprec   19       D          xml
# 53       totalpdbf   18       D          xml
#
#                                              download  \
# 0   {'name': 'C2_PrecioFinal', 'url': '/archives/1...
# 1   {'name': 'C5_PrecioFinal', 'url': '/archives/1...
# ..                                                ...
# 52  {'name': 'totalrpdvpprec', 'url': '/archives/1...
# 53  {'name': 'totalpdbf', 'url': '/archives/18/dow...
#
#                                                  date  \
# 0   {'date_type': 'datos', 'start_date': '2023-01-...
# 1   {'date_type': 'datos', 'start_date': '2023-01-...
# ..                                                ...
# 52  {'date_type': 'datos', 'start_date': '2023-01-...
# 53  {'date_type': 'datos', 'start_date': '2023-01-...
#
# ...

# %% [markdown]
# ## Unidades

# %% [markdown]
# - Unidades fisicas: https://www.esios.ree.es/es/unidades-fisicas
# - Unidades de programación: https://www.esios.ree.es/es/unidades-de-programacion
# - Sujetos del mercado: https://www.esios.ree.es/es/sujetos-del-mercado

# %% [markdown]
# ## Ficheros
# - I3DIA: Tecnología
# - IMES: [Sujeto de liquidación](https://www.esios.ree.es/es/sujetos-del-mercado)
# - I90DIA: [Unidad de programación](https://www.esios.ree.es/es/unidades-de-programacion)
