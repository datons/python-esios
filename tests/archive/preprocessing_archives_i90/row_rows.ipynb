# %% [markdown]
# # Analyze

# %% [markdown]
# ## Load files

# %% [markdown]
# - I90DIA27: Bilateral

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from esios.archives import preprocessing
from pathlib import Path

# %% [markdown]
# - 6A: Date of data
# - 6C: Date of publication
# - 10(rest of rows)AB: Table of contents

# %%
import pandas as pd

pd.set_option('future.no_silent_downcasting', True)

# %% [markdown]
# Possibilities of columns:
#
# - columns
#     - double
#     - single
# - frequency
#     - hourly
#     - hour-quarterly

# %% [markdown]
# 1. check row with more rows -> columns
# 2. check which column starts with a number; if -1, then look row up
# 3. forward fill to coordinate dates
#     - two variables: mwh and €/mwh
#     - one variable: mwh or €/mwh

# %%
# IDIA10 - quarterly hourly

# %% [markdown]
# 1. handle columns into sheet, then handle rows

# %%
from esios.archives.preprocessing import I90Book

path = '/root/projects/volume/curtailment-i90-app-db-energy/data/bucket/esios/archives/I90DIA/I90DIA_20240101/I90DIA_20240101.xls'

i90 = I90Book(path)
sheet = i90['I90DIA30']
sheet.df
# Out:
# variable                                                Precio Marginal Cuartohorario €/MWh
# Redespacho Tipo Redespacho Sentido datetime
# Terciaria  TERPRO          Subir   2024-01-01 00:00:00                                75.56
#                                    2024-01-01 00:15:00                                76.18
#                                    2024-01-01 00:30:00                                65.00
#                                    2024-01-01 00:45:00                                64.80
#                                    2024-01-01 01:00:00                                79.51
# ...                                                                                     ...
#                            Bajar   2024-01-01 22:30:00                                  NaN
#                                    2024-01-01 23:00:00                                  NaN
#                                    2024-01-01 23:15:00                                  NaN
#                                    2024-01-01 23:30:00                                14.64
#                                    2024-01-01 23:45:00                                11.10
#
# [144 rows x 1 columns]

# %%
sheet.df.reset_index()
# Out:
# variable Redespacho Tipo Redespacho Sentido            datetime  \
# 0         Terciaria          TERPRO   Subir 2024-01-01 00:00:00
# 1         Terciaria          TERPRO   Subir 2024-01-01 00:15:00
# 2         Terciaria          TERPRO   Subir 2024-01-01 00:30:00
# 3         Terciaria          TERPRO   Subir 2024-01-01 00:45:00
# 4         Terciaria          TERPRO   Subir 2024-01-01 01:00:00
# ..              ...             ...     ...                 ...
# 139       Terciaria          TERPRO   Bajar 2024-01-01 22:30:00
# 140       Terciaria          TERPRO   Bajar 2024-01-01 23:00:00
# 141       Terciaria          TERPRO   Bajar 2024-01-01 23:15:00
# 142       Terciaria          TERPRO   Bajar 2024-01-01 23:30:00
# 143       Terciaria          TERPRO   Bajar 2024-01-01 23:45:00
#
# variable  Precio Marginal Cuartohorario €/MWh
# 0                                       75.56
# 1                                       76.18
# 2                                       65.00
# 3                                       64.80
# 4                                       79.51
# ..                                        ...
# 139                                       NaN
# 140                                       NaN
# 141                                       NaN
# 142                                     14.64
# 143                                     11.10
#
# [144 rows x 5 columns]

# %%
sheet = i90['I90DIA17']
sheet.df
# Out:
# variable                                                                           MWh  \
# Sentido Unidad de Programación Bloque Tipo Oferta Precedencia datetime
# Venta   A12PAME                Blq. 1 2.0         Mercado     2024-01-01 00:00:00  0.1
#                                                               2024-01-01 01:00:00  0.1
#                                                               2024-01-01 02:00:00  0.1
#                                                               2024-01-01 03:00:00  0.1
#                                                               2024-01-01 04:00:00  0.1
# ...                                                                                ...
# Compra  ZJARVE                 Blq. 1 10.0        Mercado     2024-01-01 19:00:00  0.0
#                                                               2024-01-01 20:00:00  0.0
#                                                               2024-01-01 21:00:00  0.0
#                                                               2024-01-01 22:00:00  0.0
#                                                               2024-01-01 23:00:00  0.0
#
# variable                                                                              €/MWh
# Sentido Unidad de Programación Bloque Tipo Oferta Precedencia datetime
# Venta   A12PAME                Blq. 1 2.0         Mercado     2024-01-01 00:00:00  99999.99
#                                                               2024-01-01 01:00:00  99999.99
#                                                               2024-01-01 02:00:00  99999.99
#                                                               2024-01-01 03:00:00  99999.99
#                                                               2024-01-01 04:00:00  99999.99
# ...                                                                                     ...
# Compra  ZJARVE                 Blq. 1 10.0        Mercado     2024-01-01 19:00:00      0.00
#                                                               2024-01-01 20:00:00      0.00
#                                                               2024-01-01 21:00:00      0.00
#                                                               2024-01-01 22:00:00      0.00
#                                                               2024-01-01 23:00:00      0.00
#
# [90048 rows x 2 columns]

# %%
path = Path()
sheet_name = 'I90DIA30'

rows_i, row_j, row, rows = preprocessing.process_excel_file(path, sheet_name)

# %%
import numpy as np
import pandas as pd

# %%
pd.DataFrame(rows_i, columns=row).set_index(row_j)
# Out:
#                                                      Indicadores  Total MW  \
# Unidad de Programación Bloque Nº Oferta  Tipo Oferta
# ACE3                   Blq. 1 20025993.0 1.0                        3088.0
# ALG3                   Blq. 1 20026008.0 1.0                        1944.8
#                        Blq. 2 20026008.0 1.0                        1448.5
#                        Blq. 3 20026008.0 1.0                        1448.5
#                        Blq. 4 20026008.0 1.0                        1448.4
# ...                                                          ...       ...
# TAPOWER                Blq. 1 20026005.0 1.0                        3335.2
# TARRAG                 Blq. 1 20026006.0 1.0                        1760.0
#                        Blq. 2 20026006.0 1.0                         560.0
#                        Blq. 3 20026006.0 1.0                         560.0
#                        Blq. 4 20026006.0 1.0                         206.4
#
#                                                       PMP €/MWh MW €/MWh MW  \
# Unidad de Programación Bloque Nº Oferta  Tipo Oferta
# ACE3                   Blq. 1 20025993.0 1.0           63.21000
# ALG3                   Blq. 1 20026008.0 1.0          377.83000
#                        Blq. 2 20026008.0 1.0          378.29347
#                        Blq. 3 20026008.0 1.0          428.29347
#                        Blq. 4 20026008.0 1.0          428.78129
# ...                                                         ... ..   ... ..
# TAPOWER                Blq. 1 20026005.0 1.0           71.70500
# TARRAG                 Blq. 1 20026006.0 1.0          253.37000
#                        Blq. 2 20026006.0 1.0          253.87000
#                        Blq. 3 20026006.0 1.0          254.37000
#                        Blq. 4 20026006.0 1.0          329.37000
#
#                                                      €/MWh MW €/MWh MW  ...  \
# Unidad de Programación Bloque Nº Oferta  Tipo Oferta                    ...
# ACE3                   Blq. 1 20025993.0 1.0                            ...
# ALG3                   Blq. 1 20026008.0 1.0                            ...
#                        Blq. 2 20026008.0 1.0                            ...
#                        Blq. 3 20026008.0 1.0                            ...
#                        Blq. 4 20026008.0 1.0                            ...
# ...                                                    ... ..   ... ..  ...
# TAPOWER                Blq. 1 20026005.0 1.0                            ...
# TARRAG                 Blq. 1 20026006.0 1.0                            ...
#                        Blq. 2 20026006.0 1.0                            ...
#                        Blq. 3 20026006.0 1.0                            ...
#                        Blq. 4 20026006.0 1.0                            ...
#
#                                                          MW   €/MWh     MW  \
# Unidad de Programación Bloque Nº Oferta  Tipo Oferta
# ACE3                   Blq. 1 20025993.0 1.0          386.0   48.21  386.0
# ALG3                   Blq. 1 20026008.0 1.0          243.1  201.45  243.1
#                        Blq. 2 20026008.0 1.0          181.2  201.95  181.5
#                        Blq. 3 20026008.0 1.0          181.2  251.95  181.5
#                        Blq. 4 20026008.0 1.0          181.2  252.45  181.6
# ...                                                     ...     ...    ...
# TAPOWER                Blq. 1 20026005.0 1.0          416.9   59.20  416.9
# TARRAG                 Blq. 1 20026006.0 1.0          220.0  253.37  220.0
#                        Blq. 2 20026006.0 1.0           70.0  253.87   70.0
#                        Blq. 3 20026006.0 1.0           70.0  254.37   70.0
#                        Blq. 4 20026006.0 1.0           25.8  329.37   25.8
#
#                                                        €/MWh     MW   €/MWh  \
# Unidad de Programación Bloque Nº Oferta  Tipo Oferta
# ACE3                   Blq. 1 20025993.0 1.0           48.21  386.0   48.21
# ALG3                   Blq. 1 20026008.0 1.0          201.45  243.1  201.45
#                        Blq. 2 20026008.0 1.0          201.95  181.7  201.95
#                        Blq. 3 20026008.0 1.0          251.95  181.7  251.95
#                        Blq. 4 20026008.0 1.0          252.45  181.6  252.45
# ...                                                      ...    ...     ...
# TAPOWER                Blq. 1 20026005.0 1.0           59.20  416.9   59.20
# TARRAG                 Blq. 1 20026006.0 1.0          253.37  220.0  253.37
#                        Blq. 2 20026006.0 1.0          253.87   70.0  253.87
#                        Blq. 3 20026006.0 1.0          254.37   70.0  254.37
#                        Blq. 4 20026006.0 1.0          329.37   25.8  329.37
#
#                                                      MW €/MWh MW €/MWh
# Unidad de Programación Bloque Nº Oferta  Tipo Oferta
# ACE3                   Blq. 1 20025993.0 1.0
# ALG3                   Blq. 1 20026008.0 1.0
#                        Blq. 2 20026008.0 1.0
#                        Blq. 3 20026008.0 1.0
#                        Blq. 4 20026008.0 1.0
# ...                                                  ..   ... ..   ...
# TAPOWER                Blq. 1 20026005.0 1.0
# TARRAG                 Blq. 1 20026006.0 1.0
#                        Blq. 2 20026006.0 1.0
#                        Blq. 3 20026006.0 1.0
#                        Blq. 4 20026006.0 1.0
#
# [82 rows x 51 columns]

# %%
## Start process of going to upper row for numbers

# %%
idx_column_start = get_idx_column_start(columns_prior)
idx_column_start
# Out:
# 7

# %%
df.melt(ignore_index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda/envs/work/lib/python3.12/site-packages/pandas/core/indexes/multi.py:1664, in MultiIndex._get_level_number(self, level)
#    1663 try:
# -> 1664     level = self.names.index(level)
#    1665 except ValueError as err:
#
# ValueError: 'variable' is not in list
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.melt(ignore_index=False).unstack('variable')
#
# File ~/miniconda/envs/work/lib/python3.12/site-packages/pandas/core/frame.py:9928, in DataFrame.unstack(self, level, fill_value, sort)
#    9864 """
#    9865 Pivot a level of the (necessarily hierarchical) index labels.
#    9866
#    (...)
#    9924 dtype: float64
#    9925 """
#    9926 from pandas.core.reshape.reshape import unstack
# -> 9928 result = unstack(self, level, fill_value, sort)
#    9930 return result.__finalize__(self, method="unstack")
#
# File ~/miniconda/envs/work/lib/python3.12/site-packages/pandas/core/reshape/reshape.py:500, in unstack(obj, level, fill_value, sort)
#     496         level = level[0]
#     498 if not is_integer(level) and not level == "__placeholder__":
#     499     # check if level is valid in case of regular index
# --> 500     obj.index._get_level_number(level)
#     502 if isinstance(obj, DataFrame):
#     503     if isinstance(obj.index, MultiIndex):
#
# File ~/miniconda/envs/work/lib/python3.12/site-packages/pandas/core/indexes/multi.py:1667, in MultiIndex._get_level_number(self, level)
#    1665 except ValueError as err:
#    1666     if not is_integer(level):
# -> 1667         raise KeyError(f"Level {level} not found") from err
#    1668     if level < 0:
#    1669         level += self.nlevels
#
# KeyError: 'Level variable not found'

# %%
idx
# Out:
# np.int64(2)

# %%
max_index = len_rows.index(max(len_rows))
max_index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 max_index = len_rows.index(max(len_rows))
#       2 max_index
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
row_j
# Out:
# ['Unidad de Programación', 'Bloque', 'Nº Oferta', 'Tipo Oferta']

# %%
row_j
# Out:
# ['Unidad de Programación', 'Bloque', 'Nº Oferta', 'Tipo Oferta']

# %%
pd.DataFrame(rows_i, columns=row).set_index(row_j)
# Out:
#                                                      Indicadores  Total MW  \
# Unidad de Programación Bloque Nº Oferta  Tipo Oferta
# ACE3                   Blq. 1 20025993.0 1.0                        3088.0
# ALG3                   Blq. 1 20026008.0 1.0                        1944.8
#                        Blq. 2 20026008.0 1.0                        1448.5
#                        Blq. 3 20026008.0 1.0                        1448.5
#                        Blq. 4 20026008.0 1.0                        1448.4
# ...                                                          ...       ...
# TAPOWER                Blq. 1 20026005.0 1.0                        3335.2
# TARRAG                 Blq. 1 20026006.0 1.0                        1760.0
#                        Blq. 2 20026006.0 1.0                         560.0
#                        Blq. 3 20026006.0 1.0                         560.0
#                        Blq. 4 20026006.0 1.0                         206.4
#
#                                                       PMP €/MWh MW €/MWh MW  \
# Unidad de Programación Bloque Nº Oferta  Tipo Oferta
# ACE3                   Blq. 1 20025993.0 1.0           63.21000
# ALG3                   Blq. 1 20026008.0 1.0          377.83000
#                        Blq. 2 20026008.0 1.0          378.29347
#                        Blq. 3 20026008.0 1.0          428.29347
#                        Blq. 4 20026008.0 1.0          428.78129
# ...                                                         ... ..   ... ..
# TAPOWER                Blq. 1 20026005.0 1.0           71.70500
# TARRAG                 Blq. 1 20026006.0 1.0          253.37000
#                        Blq. 2 20026006.0 1.0          253.87000
#                        Blq. 3 20026006.0 1.0          254.37000
#                        Blq. 4 20026006.0 1.0          329.37000
#
#                                                      €/MWh MW €/MWh MW  ...  \
# Unidad de Programación Bloque Nº Oferta  Tipo Oferta                    ...
# ACE3                   Blq. 1 20025993.0 1.0                            ...
# ALG3                   Blq. 1 20026008.0 1.0                            ...
#                        Blq. 2 20026008.0 1.0                            ...
#                        Blq. 3 20026008.0 1.0                            ...
#                        Blq. 4 20026008.0 1.0                            ...
# ...                                                    ... ..   ... ..  ...
# TAPOWER                Blq. 1 20026005.0 1.0                            ...
# TARRAG                 Blq. 1 20026006.0 1.0                            ...
#                        Blq. 2 20026006.0 1.0                            ...
#                        Blq. 3 20026006.0 1.0                            ...
#                        Blq. 4 20026006.0 1.0                            ...
#
#                                                          MW   €/MWh     MW  \
# Unidad de Programación Bloque Nº Oferta  Tipo Oferta
# ACE3                   Blq. 1 20025993.0 1.0          386.0   48.21  386.0
# ALG3                   Blq. 1 20026008.0 1.0          243.1  201.45  243.1
#                        Blq. 2 20026008.0 1.0          181.2  201.95  181.5
#                        Blq. 3 20026008.0 1.0          181.2  251.95  181.5
#                        Blq. 4 20026008.0 1.0          181.2  252.45  181.6
# ...                                                     ...     ...    ...
# TAPOWER                Blq. 1 20026005.0 1.0          416.9   59.20  416.9
# TARRAG                 Blq. 1 20026006.0 1.0          220.0  253.37  220.0
#                        Blq. 2 20026006.0 1.0           70.0  253.87   70.0
#                        Blq. 3 20026006.0 1.0           70.0  254.37   70.0
#                        Blq. 4 20026006.0 1.0           25.8  329.37   25.8
#
#                                                        €/MWh     MW   €/MWh  \
# Unidad de Programación Bloque Nº Oferta  Tipo Oferta
# ACE3                   Blq. 1 20025993.0 1.0           48.21  386.0   48.21
# ALG3                   Blq. 1 20026008.0 1.0          201.45  243.1  201.45
#                        Blq. 2 20026008.0 1.0          201.95  181.7  201.95
#                        Blq. 3 20026008.0 1.0          251.95  181.7  251.95
#                        Blq. 4 20026008.0 1.0          252.45  181.6  252.45
# ...                                                      ...    ...     ...
# TAPOWER                Blq. 1 20026005.0 1.0           59.20  416.9   59.20
# TARRAG                 Blq. 1 20026006.0 1.0          253.37  220.0  253.37
#                        Blq. 2 20026006.0 1.0          253.87   70.0  253.87
#                        Blq. 3 20026006.0 1.0          254.37   70.0  254.37
#                        Blq. 4 20026006.0 1.0          329.37   25.8  329.37
#
#                                                      MW €/MWh MW €/MWh
# Unidad de Programación Bloque Nº Oferta  Tipo Oferta
# ACE3                   Blq. 1 20025993.0 1.0
# ALG3                   Blq. 1 20026008.0 1.0
#                        Blq. 2 20026008.0 1.0
#                        Blq. 3 20026008.0 1.0
#                        Blq. 4 20026008.0 1.0
# ...                                                  ..   ... ..   ...
# TAPOWER                Blq. 1 20026005.0 1.0
# TARRAG                 Blq. 1 20026006.0 1.0
#                        Blq. 2 20026006.0 1.0
#                        Blq. 3 20026006.0 1.0
#                        Blq. 4 20026006.0 1.0
#
# [82 rows x 51 columns]

# %%
import pandas as pd

pd.DataFrame(rows[i:])
# Out:
#                         0       1          2            3            4   \
# 0                                                                   Dia
# 1                                                                  Hora
# 2   Unidad de Programación  Bloque  Nº Oferta  Tipo Oferta  Indicadores
# 3                     ACE3  Blq. 1   20025993          1.0
# 4                     ALG3  Blq. 1   20026008          1.0
# ..                     ...     ...        ...          ...          ...
# 80                 TAPOWER  Blq. 1   20026005          1.0
# 81                  TARRAG  Blq. 1   20026006          1.0
# 82                  TARRAG  Blq. 2   20026006          1.0
# 83                  TARRAG  Blq. 3   20026006          1.0
# 84                  TARRAG  Blq. 4   20026006          1.0
#
#                          5          6      7      8      9   ...     45  \
# 0                2014-01-10                                  ...
# 1   Total MW y Precio Medio             00-01         01-02  ...  19-20
# 2                  Total MW  PMP €/MWh     MW  €/MWh     MW  ...     MW
# 3                    3088.0      63.21                       ...  386.0
# 4                    1944.8     377.83                       ...  243.1
# ..                      ...        ...    ...    ...    ...  ...    ...
# 80                   3335.2     71.705                       ...  416.9
# 81                   1760.0     253.37                       ...  220.0
# 82                    560.0     253.87                       ...   70.0
# 83                    560.0     254.37                       ...   70.0
# 84                    206.4     329.37                       ...   25.8
#
#         46     47      48     49      50     51     52     53     54
# 0
# 1           20-21          21-22          22-23         23-24
# 2    €/MWh     MW   €/MWh     MW   €/MWh     MW  €/MWh     MW  €/MWh
# 3    48.21  386.0   48.21  386.0   48.21
# 4   201.45  243.1  201.45  243.1  201.45
# ..     ...    ...     ...    ...     ...    ...    ...    ...    ...
# 80    59.2  416.9    59.2  416.9    59.2
# 81  253.37  220.0  253.37  220.0  253.37
# 82  253.87   70.0  253.87   70.0  253.87
# 83  254.37   70.0  254.37   70.0  254.37
# 84  329.37   25.8  329.37   25.8  329.37
#
# [85 rows x 55 columns]

# %%
row
# Out:
# ['Unidad de Programación',
#  'Bloque',
#  'Nº Oferta',
#  'Tipo Oferta',
#  'Indicadores',
#  'Total MW',
#  'PMP €/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh',
#  'MW',
#  '€/MWh']

# %%
df_base
# Out:
#      Redespacho Sentido Unidad de Programación  Nm Oferta asignada  \
# 0       UPOPVPV   Subir                   ABO2            31445465
# 1       UPOPVPV   Subir                   ACE4            31445583
# ...         ...     ...                    ...                 ...
# 4030   ECOBCBSO   Bajar                   GDNA            25451783
# 4031   ECOBCBSO   Bajar                   TERE            25451786
#
#       Tipo Oferta Tipo cálculo Tipo Restricción                  datetime  \
# 0               1     Complejo              RTD 2024-02-21 00:00:00+01:00
# 1               1     Complejo              SOT 2024-02-21 00:00:00+01:00
# ...           ...          ...              ...                       ...
# 4030            1    No aplica              NaN 2024-02-21 23:00:00+01:00
# 4031            1    No aplica              NaN 2024-02-21 23:00:00+01:00
#
#       value
# 0       NaN
# 1     116.6
# ...     ...
# 4030    NaN
# 4031    NaN
#
# [4032 rows x 9 columns]

# %%
values = ['RTD', 'SOT'] # curtailment

df = df.query('')
# Out:
# ['RTD', 'SOT']

# %% [markdown]
# ### Unit specific involved in contracts

# %%
unit = "ENDE01"
contracts = df_base.query('unit == @unit').contract.unique()
contracts
# Out:
# array([1019, 1513, 1994, 2293, 2193, 2330])

# %%
mask = df_base.contract.isin(contracts)
df = df_base[mask]
df
# Out:
#        unit  offer_type  contract   hour  value            datetime   agent
# 12     ALZ1           1      1994  00-01    NaN 2024-02-21 00:00:00  Seller
# 16     ALZ2           1      1994  00-01    NaN 2024-02-21 00:00:00  Seller
# ...     ...         ...       ...    ...    ...                 ...     ...
# 12214  TERE           1      1513  23-24    NaN 2024-02-21 23:00:00  Seller
# 12241  VAN2           1      1513  23-24    NaN 2024-02-21 23:00:00  Seller
#
# [696 rows x 7 columns]

# %%
df.groupby(['unit', 'agent']).value.sum().unstack('agent').sort_values('Buyer', ascending=False).fillna(0).style.format(precision=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6a769">
#   <thead>
#     <tr>
#       <th class="index_name level0" >agent</th>
#       <th id="T_6a769_level0_col0" class="col_heading level0 col0" >Buyer</th>
#       <th id="T_6a769_level0_col1" class="col_heading level0 col1" >Seller</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >unit</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a769_level0_row0" class="row_heading level0 row0" >ASC1</th>
#       <td id="T_6a769_row0_col0" class="data row0 col0" >2985</td>
#       <td id="T_6a769_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row1" class="row_heading level0 row1" >ASC2</th>
#       <td id="T_6a769_row1_col0" class="data row1 col0" >2526</td>
#       <td id="T_6a769_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row2" class="row_heading level0 row2" >VAN2</th>
#       <td id="T_6a769_row2_col0" class="data row2 col0" >2256</td>
#       <td id="T_6a769_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row3" class="row_heading level0 row3" >EBRFEN</th>
#       <td id="T_6a769_row3_col0" class="data row3 col0" >1644</td>
#       <td id="T_6a769_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row4" class="row_heading level0 row4" >SBEU</th>
#       <td id="T_6a769_row4_col0" class="data row4 col0" >1230</td>
#       <td id="T_6a769_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row5" class="row_heading level0 row5" >ENDE01</th>
#       <td id="T_6a769_row5_col0" class="data row5 col0" >589</td>
#       <td id="T_6a769_row5_col1" class="data row5 col1" >-12182</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row6" class="row_heading level0 row6" >ALZ2</th>
#       <td id="T_6a769_row6_col0" class="data row6 col0" >342</td>
#       <td id="T_6a769_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row7" class="row_heading level0 row7" >ALZ1</th>
#       <td id="T_6a769_row7_col0" class="data row7 col0" >342</td>
#       <td id="T_6a769_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row8" class="row_heading level0 row8" >EREGPE1</th>
#       <td id="T_6a769_row8_col0" class="data row8 col0" >149</td>
#       <td id="T_6a769_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row9" class="row_heading level0 row9" >EREGPEM</th>
#       <td id="T_6a769_row9_col0" class="data row9 col0" >128</td>
#       <td id="T_6a769_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row10" class="row_heading level0 row10" >EEGPEM</th>
#       <td id="T_6a769_row10_col0" class="data row10 col0" >126</td>
#       <td id="T_6a769_row10_col1" class="data row10 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row11" class="row_heading level0 row11" >GDLQ</th>
#       <td id="T_6a769_row11_col0" class="data row11 col0" >115</td>
#       <td id="T_6a769_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row12" class="row_heading level0 row12" >GDNA</th>
#       <td id="T_6a769_row12_col0" class="data row12 col0" >102</td>
#       <td id="T_6a769_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row13" class="row_heading level0 row13" >TEES</th>
#       <td id="T_6a769_row13_col0" class="data row13 col0" >60</td>
#       <td id="T_6a769_row13_col1" class="data row13 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row14" class="row_heading level0 row14" >FEGPE1</th>
#       <td id="T_6a769_row14_col0" class="data row14 col0" >47</td>
#       <td id="T_6a769_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row15" class="row_heading level0 row15" >FREGPEM</th>
#       <td id="T_6a769_row15_col0" class="data row15 col0" >46</td>
#       <td id="T_6a769_row15_col1" class="data row15 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row16" class="row_heading level0 row16" >HEGPE</th>
#       <td id="T_6a769_row16_col0" class="data row16 col0" >34</td>
#       <td id="T_6a769_row16_col1" class="data row16 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row17" class="row_heading level0 row17" >FEGPEM</th>
#       <td id="T_6a769_row17_col0" class="data row17 col0" >24</td>
#       <td id="T_6a769_row17_col1" class="data row17 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row18" class="row_heading level0 row18" >FEGPE2</th>
#       <td id="T_6a769_row18_col0" class="data row18 col0" >12</td>
#       <td id="T_6a769_row18_col1" class="data row18 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row19" class="row_heading level0 row19" >TERE</th>
#       <td id="T_6a769_row19_col0" class="data row19 col0" >6</td>
#       <td id="T_6a769_row19_col1" class="data row19 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row20" class="row_heading level0 row20" >FREGPE</th>
#       <td id="T_6a769_row20_col0" class="data row20 col0" >5</td>
#       <td id="T_6a769_row20_col1" class="data row20 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row21" class="row_heading level0 row21" >FEGPE</th>
#       <td id="T_6a769_row21_col0" class="data row21 col0" >4</td>
#       <td id="T_6a769_row21_col1" class="data row21 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row22" class="row_heading level0 row22" >ECAZC01</th>
#       <td id="T_6a769_row22_col0" class="data row22 col0" >0</td>
#       <td id="T_6a769_row22_col1" class="data row22 col1" >-578</td>
#     </tr>
#     <tr>
#       <th id="T_6a769_level0_row23" class="row_heading level0 row23" >EPRSC01</th>
#       <td id="T_6a769_row23_col0" class="data row23 col0" >0</td>
#       <td id="T_6a769_row23_col1" class="data row23 col1" >-12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## References
#
# https://www.energychisquared.com/post/tipos-de-bilaterales-en-el-sistema-el%C3%A9ctrico/
